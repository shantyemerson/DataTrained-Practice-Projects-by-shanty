# %% [markdown]
# #  BIGMART SALES PREDICTION

# %% [markdown]
# **OBJECTIVE:** The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and find out the sales of each product at a particular store.
#
# Using this model, BigMart will try to understand the properties of products and stores which play a key role in increasing the sales of their products.
#
# Target variable is item_outlet_Sales. And we are predicting the sale price for a given product, hence we use regression algorithms.

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### LOADING DATA

# %%
#Loading training data
dtrain=pd.read_csv("Bigmart_train.csv")

#loading testing data
dtest=pd.read_csv("Bigmart_test.csv")
                  
#train data sample
dtrain.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#test data sample
dtest.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
# size/Dimensions of train data
dtrain.shape
# Out:
# (8523, 12)

# %%
#size/dimensions of test data
dtest.shape
# Out:
# (5681, 11)

# %% [markdown]
# If we observe shapes of both data, train data has one additional column, which is tha target feature Item_Outlet_Sales.

# %%
# statistical info of train data
dtrain.describe().T
# Out:
#                             count         mean          std       min  \
# Item_Weight                7060.0    12.857645     4.643456     4.555
# Item_Visibility            8523.0     0.066132     0.051598     0.000
# Item_MRP                   8523.0   140.992782    62.275067    31.290
# Outlet_Establishment_Year  8523.0  1997.831867     8.371760  1985.000
# Item_Outlet_Sales          8523.0  2181.288914  1706.499616    33.290
#
#                                    25%          50%          75%           max
# Item_Weight                   8.773750    12.600000    16.850000     21.350000
# Item_Visibility               0.026989     0.053931     0.094585      0.328391
# Item_MRP                     93.826500   143.012800   185.643700    266.888400
# Outlet_Establishment_Year  1987.000000  1999.000000  2004.000000   2009.000000
# Item_Outlet_Sales           834.247400  1794.331000  3101.296400  13086.964800

# %% [markdown]
# Item weight is missing values.

# %%
#checking datatype of attributes
dtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# There are numerical attributes as well as categorical.

# %% [markdown]
# ### PREPROCESSING DATA (EDA)

# %%
# checking null values of train data
dtrain.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# We have 1463 null values in item_weight and 2410 in outlet_size.

# %%
# checking null values of test data
dtest.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# We have 976 null values in item_weight and 1606 in outlet_size.

# %%
# Concatenating Train data and test data.
# Adding an extra column to identify data source train or test.

dtrain['source']= 'Train'
dtest['source'] = 'Test'
df= pd.concat([dtrain,dtest])

# %%
#New column source added with source as train or test.
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# New size of data.
df.shape
# Out:
# (14204, 13)

# %%
# cecking null values
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %% [markdown]
# Here we can see null values in Item_Outlet_Sales came as we merged both datas and test data is filled with Nan values as it doesnt contain mentioned column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14204 entries, 0 to 5680
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11765 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  source                     14204 non-null  object
# ...

# %% [markdown]
# we have total 8 objects which is categorical data, which we have to deal separately.

# %%
#Filter categorical variables
categorical_columns = [x for x in df.dtypes.index if df.dtypes[x]=='object']
#Exclude ID cols and source:
categorical_columns = [x for x in categorical_columns if x not in ['Item_Identifier','Outlet_Identifier','source']]
#Print frequency of categories
for col in categorical_columns:
    print('\nFrequency of Categories for varible %s'%col)
    print(df[col].value_counts())
# Out:
# Frequency of Categories for varible Item_Fat_Content
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64
#
# Frequency of Categories for varible Item_Type
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64
#
# Frequency of Categories for varible Outlet_Size
# Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64
#
# Frequency of Categories for varible Outlet_Location_Type
# Tier 3    5583
# ...

# %% [markdown]
# Item_Fat_Content: Some of ‘Low Fat’ values mis-coded as ‘low fat’ and ‘LF’. Also, some of ‘Regular’ are mentioned as ‘regular’.

# %% [markdown]
# **VISUALIZATIONS**

# %%
# Distribution of target variable.
sns.distplot(df['Item_Outlet_Sales'].dropna())
plt.title("Item_Outlet_Sales Distribution")
# Out:
# Text(0.5, 1.0, 'Item_Outlet_Sales Distribution')

# %% [markdown]
# Positively skewed data, therefore we have to normalize it.

# %%
# Now we will consider our dependent variables. First of all, we will check for the numerical variables in our dataset:
num_col = dtrain.select_dtypes(include=[np.number])
num_col.dtypes
# Out:
# Item_Weight                  float64
# Item_Visibility              float64
# Item_MRP                     float64
# Outlet_Establishment_Year      int64
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# **Correlation between Numeric Features and Target variable**
# correlation between our dependent variables and target variable.

# %%
corr=num_col.corr()
corr
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
# Item_Weight and Item_Outlet_Sales analysis
plt.figure(figsize=(10,8))
plt.plot(dtrain.Item_Weight, dtrain["Item_Outlet_Sales"],'.', alpha = 0.3)

# %% [markdown]
# Item_Weight had a low correlation with our target variable.

# %%
# Item_Visibility and Item_Outlet_Sales analysis
plt.figure(figsize=(10,8))
plt.title("Item_Visibility and Item_Outlet_Sales Analysis")
plt.plot(dtrain['Item_Visibility'], dtrain["Item_Outlet_Sales"],'.', alpha = 0.3)

# %%
# Outlet_Establishment_Year and Item_Outlet_Sales analysis
Outlet_Establishment_Year_pivot = dtrain.pivot_table(index='Outlet_Establishment_Year', values="Item_Outlet_Sales", aggfunc=np.median)
Outlet_Establishment_Year_pivot.plot(kind='bar', color='blue',figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year'>

# %% [markdown]
# There is no relation between outlet_estabishment_year and item_outlet sales.

# %%
#Item_Fat_Content onItem_Outlet_Sales
Item_Fat_Content_pivot = dtrain.pivot_table(index='Item_Fat_Content', values="Item_Outlet_Sales", aggfunc=np.median)
Item_Fat_Content_pivot.plot(kind='bar', color='blue',figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content'>

# %% [markdown]
# Low fat products has higher demand than full fat/regular diary products.

# %%
# Outlet_Identifier on Item_Outlet_Sales
Outlet_Identifier_pivot = dtrain.pivot_table(index='Outlet_Identifier', values="Item_Outlet_Sales", aggfunc=np.median)
Outlet_Identifier_pivot.plot(kind='bar', color='blue',figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier'>

# %%
# Outlet_size on Item_Outlet_type

dtrain.pivot_table(values='Outlet_Type',
                  columns='Outlet_Identifier',
                  aggfunc=lambda x:x.mode())
# Out:
# Outlet_Identifier         OUT010             OUT013             OUT017  \
# Outlet_Type        Grocery Store  Supermarket Type1  Supermarket Type1
#
# Outlet_Identifier             OUT018         OUT019             OUT027  \
# Outlet_Type        Supermarket Type2  Grocery Store  Supermarket Type3
#
# Outlet_Identifier             OUT035             OUT045             OUT046  \
# Outlet_Type        Supermarket Type1  Supermarket Type1  Supermarket Type1
#
# Outlet_Identifier             OUT049
# Outlet_Type        Supermarket Type1

# %% [markdown]
# Out of 10- There are 2 Groceries strore, 6 Supermarket Type1, 1Supermarket Type2, and 1 Supermarket Type3.

# %%
# Outlet_Size on Item_Outlet_Sales

Outlet_Size_pivot = dtrain.pivot_table(index='Outlet_Size', values="Item_Outlet_Sales", aggfunc=np.median)
Outlet_Size_pivot.plot(kind='bar', color='blue',figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Outlet_Size'>

# %%
# Outlet_Type on Item_Outlet_Sales
Outlet_Type_pivot = dtrain.pivot_table(index='Outlet_Type', values="Item_Outlet_Sales", aggfunc=np.median)
Outlet_Type_pivot.plot(kind='bar', color='blue',figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Outlet_Type'>

# %% [markdown]
# Sales are on higher side for type 3 supermarkets.

# %%
# Outlet_Location_Type on Item_Outlet_Sales
Outlet_Location_Type_pivot = dtrain.pivot_table(index='Outlet_Location_Type', values="Item_Outlet_Sales", aggfunc=np.median)
Outlet_Location_Type_pivot.plot(kind='bar', color='blue',figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type'>

# %% [markdown]
# ### DATA CLEANING

# %%
# imputing missing values

df['Item_Weight'] = df['Item_Weight'].replace(0, np.NaN)
df['Item_Weight'].fillna(df['Item_Weight'].mean(), inplace = True)

df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0], inplace = True)

df['Item_Outlet_Sales'] = df['Item_Outlet_Sales'].replace(0, np.NaN)
df['Item_Outlet_Sales'].fillna(df['Item_Outlet_Sales'].mode()[0], inplace = True)

df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# source                       0
# dtype: int64

# %%
# combining reg, Regular and Low Fat, low fat and, LF


df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({'LF': 'Low Fat', 'reg': 'Regular', 'low fat': 'Low Fat'})
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    9185
# Regular    5019
# Name: Item_Fat_Content, dtype: int64

# %%
# Getting the first two characters of ID to separate them into different categories

df['Item_Identifier'] = df['Item_Identifier'].apply(lambda x: x[0:2])

df['Item_Identifier'] = df['Item_Identifier'].map({'FD':'Food', 'NC':'Non_Consumable', 'DR':'Drinks'})

df['Item_Identifier'].value_counts()
# Out:
# Food              10201
# Non_Consumable     2686
# Drinks             1317
# Name: Item_Identifier, dtype: int64

# %%
# determining the operation peroid of a time

df['Outlet_Years'] = 2013 - df['Outlet_Establishment_Year']
df['Outlet_Years'].value_counts()
# Out:
# 28    2439
# 26    1553
# 14    1550
# 9     1550
# 16    1550
# 11    1548
# 4     1546
# 6     1543
# 15     925
# Name: Outlet_Years, dtype: int64

# %%
# removing unnecassary columns from the dataset

#data = df.drop('Item_Identifier', axis = 1)

#print(data.shape)
# Out:
# (14204, 13)

# %%
df['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    9294
# Grocery Store        1805
# Supermarket Type3    1559
# Supermarket Type2    1546
# Name: Outlet_Type, dtype: int64

# %%
# label encoding

from sklearn.preprocessing import LabelEncoder

df.apply(LabelEncoder().fit_transform)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            Food         9.30          Low Fat         0.016047
# 1          Drinks         5.92          Regular         0.019278
# 2            Food        17.50          Low Fat         0.016760
# 3            Food        19.20          Regular         0.000000
# 4  Non_Consumable         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# one hot encoding

data = pd.get_dummies(data)

print(data.shape)
# Out:
# (14204, 46)

# %%
# splitting the data into dependent and independent variables

x = data.drop('Item_Outlet_Sales', axis = 1)
y = data.Item_Outlet_Sales

print(x.shape)
print(y.shape)
# Out:
# (14204, 45)
# (14204,)

# %%
# splitting the dataset into train and test

train = data.iloc[:8523,:]
test = data.iloc[8523:,:]

print(train.shape)
print(test.shape)
# Out:
# (8523, 46)
# (5681, 46)

# %%
# making x_train, x_test, y_train, y_test

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (9942, 45)
# (9942,)
# (4262, 45)
# (4262,)

# %% [markdown]
# **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

model = LinearRegression()
model.fit(x_train, y_train)

# predicting the  test set results
y_pred = model.predict(x_test)
print(y_pred)

# finding the mean squared error and variance
mse = mean_squared_error(y_test, y_pred)
print('RMSE :', np.sqrt(mse))
print('Variance score: %.2f' % r2_score(y_test, y_pred))
# Out:
# [ 100.03236739 1641.77947055 1383.61354106 ... 2733.04406933 1116.59426231
#    38.80917425]
# RMSE : 1078.542275233661
# Variance score: 0.44

# %% [markdown]
# **Support vector machine**

# %%
from sklearn.svm import SVR

model2= SVR()
model2.fit(x_train, y_train)

# predicting the x test results
y_pred = model.predict(x_test)

# Calculating the RMSE Score
mse = mean_squared_error(y_test, y_pred)
print("RMSE :", np.sqrt(mse))
# Out:
# RMSE : 1622.827422113382
